# %% [markdown]
# # Normal Distribution <hr style = "border:2.5px solid #0000FF"></hr>

# %% [markdown]
# <b> Rendon Jericho A. </b>
# <br>Comptech Student T09
# <br> 01/20/2026

# %% [markdown]
# # Import Libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# # Z-Score

# %%
df = pd.DataFrame([1,2,2,3,3,3,4,4,5],
                  columns=['DATASET'])
df
# Out:
#    DATASET
# 0        1
# 1        2
# 2        2
# 3        3
# 4        3
# 5        3
# 6        4
# 7        4
# 8        5

# %%
# summary of statistics
df.describe()
# Out:
#         DATASET
# count  9.000000
# mean   3.000000
# std    1.224745
# min    1.000000
# 25%    2.000000
# 50%    3.000000
# 75%    4.000000
# max    5.000000

# %%
# Z-scores results

df['Z-score'] = stats.zscore (df['DATASET'],ddof=1)
df
# Out:
#    DATASET   Z-score
# 0        1 -1.632993
# 1        2 -0.816497
# 2        2 -0.816497
# 3        3  0.000000
# 4        3  0.000000
# 5        3  0.000000
# 6        4  0.816497
# 7        4  0.816497
# 8        5  1.632993

# %% [markdown]
# # Testing the Dataset

# %%
df = pd.read_csv(r"C:\Users\ASUS\OneDrive\Desktop\dataset\current-power.csv",
                    delimiter=',')
df = df.set_index('Sample') if 'Sample' in df.columns else df
df
# Out:
#    Current  Power
# 0      2.0    100
# 1      3.5    200
# 2      1.8     90
# 3      4.2    210
# 4      2.7    110

# %%
df['Current'][2]
# Out:
# np.float64(1.8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Current  5 non-null      float64
#  1   Power    5 non-null      int64
# dtypes: float64(1), int64(1)
# memory usage: 212.0 bytes

# %%
# summary of statistics
df.describe()
# Out:
#         Current       Power
# count  5.000000    5.000000
# mean   2.840000  142.000000
# std    1.011435   58.051701
# min    1.800000   90.000000
# 25%    2.000000  100.000000
# 50%    2.700000  110.000000
# 75%    3.500000  200.000000
# max    4.200000  210.000000

# %%
# Z-scores results

df['Z-score'] = stats.zscore (df['Current'],ddof=1)
df
# Out:
#    Current  Power   Z-score
# 0      2.0    100 -0.830504
# 1      3.5    200  0.652538
# 2      1.8     90 -1.028242
# 3      4.2    210  1.344625
# 4      2.7    110 -0.138417

# %%
# Z-scores summary of statistics
df['Z-score'].describe()
# Out:
# count    5.000000e+00
# mean     2.442491e-16
# std      1.000000e+00
# min     -1.028242e+00
# 25%     -8.305035e-01
# 50%     -1.384173e-01
# 75%      6.525385e-01
# max      1.344625e+00
# Name: Z-score, dtype: float64

# %% [markdown]
# # Histogram

# %%
plt.hist(df['Current'], bins=8,
         alpha=0.8,
         color='blue',
         edgecolor='black'
         )
plt.title ('Historgram of Current Values',font = 'Times New Roman', fontsize=12)
plt.xlabel('Current(mA)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Normal Distribution <hr style = "border:2.5px solid #0000FF"></hr>

# %%
mean = df['Current'].mean()
std = df['Current'].std(ddof=1)

x_min = df['Current'].min()
x_max = df['Current'].max()

x = np.linspace(x_min, x_max, 100)
p = stats.norm.pdf(x, mean, std)

plt.plot(x, p, color = (1.0, 40/255, 0.0))
plt.title ('Normal Distribtion of Current Values',font = 'Times New Roman', fontsize=12)
plt.xlabel('Current(mA)')
plt.ylabel('Probability Density')
plt.show()

# %%
plt.hist(df['Current'], bins=8,
         density= True,
         alpha=0.8,
         color='blue',
         edgecolor='black')

plt.title ('Normal Distribtion of Current Values',font = 'Times New Roman', fontsize=12)
plt.xlabel('Current(mA)')
plt.ylabel('Probability Density')

# normal distribution curve
p = stats.norm.pdf(x, mean, std)
plt.plot(x, p, color = (1.0, 40/255, 0.0))
plt.show()

# %%
# Standard Normal Distribution N(0,1)

#x-axis

x_max = df['Z-score'].max()
x_min = df['Z-score'].min()
x = np.linspace(x_min, x_max, 100)

p = stats.norm.pdf(x, df['Z-score'].mean(), df['Z-score'].std(ddof=1))

plt.plot(x,p, color = 'red', linewidth = 2)
plt.title ('Standard Normal Distribtion of Current Values N (0,1)',font = 'Times New Roman', fontsize=12)
plt.xlabel('Z-score')
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')
